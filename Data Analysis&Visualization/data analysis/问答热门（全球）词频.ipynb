# %%
import jieba
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
from wordcloud import WordCloud
import xlrd
import csv
from os import sys
import pandas as pd

# %%
df = pd.read_csv('keywords.csv',encoding = 'gb2312')
df2=df.drop(index=[1,2,5,9,12,11,15,16,18,19,26,27,29,30,32,33,34,31,35,36,37,38,39,40,45,46,47,48,52,53]).head(50)
df2
# Out:
#    keyword  frequency
# 0       旅行        202
# 3        拍         44
# 4        吃         42
# 6       怎样         34
# 7       体验         33
# 8       喜欢         32
# 10      地方         31
# 13      孩子         24
# 14      照片         24
# 17      自驾         21
# 20      特别         20
# 21      拍照         19
# 22      出去         19
# 23       看         18
# 24      自己         18
# 25      摄影         18
# 28      适合         17
# 41      经历         14
# 42      城市         14
# 43      中国         14
# 44      朋友         14
# 49       玩         12
# 50      美食         12
# 51      国外         12
# 54      愿意         12
# 55      风景         11
# 56     目的地         11
# 57      国内         11
# 58       被         11
# 59      一起         10
# 60      当地         10
# 61      重要         10
# 62       住         10
# 63    哪些地方          9
# 64      亲子          9
# 65     怎么样          9
# 66     什么样          9
# 67      东西          9
# 68      景点          9
# 69      酒店          9
# 70      食物          9
# 71     怎么办          9
# 72      手机          8
# 73      出门          8
# 74      一次          8
# 75       穿          8
# 76       把          8
# 77      或者          8
# 78      比如          8
# 79      女生          8

# %%
#keyword = df['keyword'].tolist()

# %%
from pyecharts import WordCloud
keyword = df2['keyword']
value = df2['frequency']
wordcloud = WordCloud(width=1000, height=620)
wordcloud.add('问答', keyword,value,word_size_range=[40, 100],
              shape='diamond',word_gap= 10)
wordcloud.render("global Q&A content.html")

# %%
from IPython.display import IFrame
IFrame('global Q&A content.html', width=1000, height=700)
# Out:
#         <iframe
#             width="1000"
#             height="700"
#             src="global Q&A content.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
